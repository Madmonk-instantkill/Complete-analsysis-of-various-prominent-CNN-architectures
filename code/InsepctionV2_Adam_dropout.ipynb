# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
from tensorflow.keras.models import Sequential,Model
from tensorflow.keras.layers import Dense,Flatten,Input,Conv2D,MaxPool2D,concatenate,BatchNormalization,Dropout
from keras.layers.convolutional import MaxPooling2D
from keras.layers.merge import concatenate
from keras.layers import Concatenate, Dense, LSTM, Input, concatenate
from keras.layers import Conv2D

from tensorflow.keras import layers

import tensorflow.keras as keras

import tensorflow.keras as keras

from tensorflow.keras.preprocessing.image import ImageDataGenerator

from tensorflow.keras.layers import LeakyReLU

from tensorflow.keras.datasets import cifar100
from tensorflow.keras.utils import to_categorical

from tensorflow.keras.callbacks import EarlyStopping,ModelCheckpoint

from keras.optimizers import Adam,SGD


(X_train,Y_train),(X_test,Y_test)=cifar100.load_data()
y_train,y_test=to_categorical(Y_train),to_categorical(Y_test)
X_train,X_test=X_train/255,X_test/255

aug_data=ImageDataGenerator(rotation_range=15,horizontal_flip=True,width_shift_range=0.1,height_shift_range=0.1,zoom_range=0.3)
aug_data.fit(X_train)

inputs=keras.Input(shape=(32,32,3))

a=Conv2D(filters=32,kernel_size=(3,3),padding="same",strides=2,activation=LeakyReLU(alpha=0.1))(inputs)
a=Dropout(0.05)(a)


a=Conv2D(filters=32,kernel_size=(3,3),padding="same",strides=1,activation=LeakyReLU(alpha=0.1))(a)
a=Dropout(0.05)(a)



a=Conv2D(filters=32, kernel_size=(3,3), padding="same",strides=1,activation=LeakyReLU(alpha=0.1))(a)
a=Dropout(0.05)(a)


a=(MaxPool2D(pool_size=(3,3),strides=(2,2)))(a)


a=Conv2D(filters=32, kernel_size=(3,3), padding="same",strides=1,activation=LeakyReLU(alpha=0.1))(a)
a=Dropout(0.05)(a)



a=Conv2D(filters=32, kernel_size=(3,3), padding="same",strides=2,activation=LeakyReLU(alpha=0.1))(a)
a=Dropout(0.05)(a)



a=Conv2D(filters=32, kernel_size=(3,3), padding="same",strides=1,activation=LeakyReLU(alpha=0.1))(a)
a=Dropout(0.05)(a)



#inception-1
b=Conv2D(64, (1,1), padding='same',strides=1,activation=LeakyReLU(alpha=0.1))(a)
b=Dropout(0.05)(b)


b=Conv2D(64, (3,3), padding='same',strides=1 ,activation=LeakyReLU(alpha=0.1))(b)
b=Dropout(0.05)(b)


b=Conv2D(64, (3,3), padding='same', strides=1,activation=LeakyReLU(alpha=0.1))(b)
b=Dropout(0.05)(b)


c=Conv2D(64, (1,1), padding='same', strides=1, activation=LeakyReLU(alpha=0.1))(a)
c=Dropout(0.05)(c)

c=Conv2D(64, (3,3), padding='same', strides=1, activation=LeakyReLU(alpha=0.1))(c)
c=Dropout(0.05)(c)


d=MaxPooling2D((3,3), strides=(1,1), padding='same')(a)
d=Dropout(0.05)(d)

d=Conv2D(64, (1,1), padding='same', strides=1, activation=LeakyReLU(alpha=0.1))(d)
d=Dropout(0.05)(d)


e=Conv2D(64, (1,1), padding='same', strides=1, activation=LeakyReLU(alpha=0.1))(a)
e=Dropout(0.05)(e)


a=concatenate([b, c, d,e],axis=3)
#a=Dropout(0.05)(a)


#inception-2
f=Conv2D(128, (1,1), padding='same', strides=1, activation=LeakyReLU(alpha=0.1))(a)
f=Dropout(0.05)(f)

f=Conv2D(128, (1,7), padding='same', strides=1, activation=LeakyReLU(alpha=0.1))(f)
f=Dropout(0.05)(f)


f=Conv2D(128, (7,1), padding='same', strides=1, activation=LeakyReLU(alpha=0.1))(f)
f=Dropout(0.05)(f)

f=Conv2D(128, (1,7), padding='same', strides=1, activation=LeakyReLU(alpha=0.1))(f)
f=Dropout(0.05)(f)


f=Conv2D(128, (7,1), padding='same', strides=1, activation=LeakyReLU(alpha=0.1))(f)
f=Dropout(0.05)(f)


g=Conv2D(128, (1,1), padding='same', strides=1, activation=LeakyReLU(alpha=0.1))(a)
g=Dropout(0.05)(g)

g=Conv2D(128, (1,7), padding='same', strides=1,activation=LeakyReLU(alpha=0.1))(g)
g=Dropout(0.05)(g)


g=Conv2D(128, (7,1), padding='same', strides=1, activation=LeakyReLU(alpha=0.1))(g)

g=Dropout(0.05)(g)


h=MaxPooling2D((3,3), strides=(1,1), padding='same')(a)
h=Dropout(0.05)(h)

h=Conv2D(128, (1,1), padding='same', strides=1, activation=LeakyReLU(alpha=0.1))(h)
h=Dropout(0.05)(h)


i=Conv2D(128, (1,1), padding='same', strides=1, activation=LeakyReLU(alpha=0.1))(h)
i=Dropout(0.05)(i)


a=concatenate([f,g,h,i],axis=3)
#a=Dropout(0.05)(a)

#inception-3
j=Conv2D(256, (1,1), padding='same', strides=1, activation=LeakyReLU(alpha=0.1))(a)
j=Dropout(0.05)(j)


j=Conv2D(256, (3,3), padding='same', strides=1, activation=LeakyReLU(alpha=0.1))(j)
j=Dropout(0.05)(j)

k=Conv2D(256, (1,3), padding='same', strides=1, activation=LeakyReLU(alpha=0.1))(j)
#k=Dropout(0.05)(k)

l=Conv2D(256, (3,1), padding='same', strides=1, activation=LeakyReLU(alpha=0.1))(j)
#l=Dropout(0.05)(l)


m=Conv2D(256, (1,1), padding='same', activation=LeakyReLU(alpha=0.1))(a)
m=Dropout(0.05)(m)

n=Conv2D(256, (1,3), padding='same', activation=LeakyReLU(alpha=0.1))(m)
#n=Dropout(0.05)(n)

o=Conv2D(256, (3,1), padding='same', activation=LeakyReLU(alpha=0.1))(m)
#o=Dropout(0.05)(o)


p=MaxPool2D((3,3), strides=(1,1), padding='same')(a)
p=Conv2D(256, (1,1), padding='same', strides=1, activation=LeakyReLU(alpha=0.1))(p)
p=Dropout(0.05)(p)


q=Conv2D(256, (1,1), padding='same', strides=1, activation=LeakyReLU(alpha=0.1))(a)
q=Dropout(0.05)(q)


a=concatenate([k,l,n,o,p,q],axis=3)
a=Dropout(0.05)(a)


a=MaxPooling2D((8,8), strides=(1,1), padding='same')(a)
#a=Dropout(0.05)(a)


a=Flatten()(a)

a=Dense(units=256,activation=LeakyReLU(alpha=0.1))(a)
a=Dropout(0.05)(a)


outputs=Dense(y_train.shape[1],activation="softmax")(a)

model=keras.Model(inputs,outputs)

adam=Adam(learning_rate=0.001,clipnorm=0.7)

#sgd=SGD(learning_rate=0.01,momentum=0.9,clipnorm=1)


model.compile(loss="categorical_crossentropy",optimizer=adam,metrics=['accuracy'])


call=EarlyStopping(monitor="val_loss",verbose=1,mode="auto",patience=10,restore_best_weights="true")

checkpoint=ModelCheckpoint('Inception_Adam_dropout.hdf5',monitor='val_accuracy',verbose=1,save_best_only=True,save_weights_only=True,model='auto',period=1)



model.fit_generator(aug_data.flow(X_train,y_train,batch_size=128),steps_per_epoch=len(X_train)/128,epochs=180,validation_data=(X_test,y_test),verbose=1,callbacks=[call,checkpoint])
# Out:
# WARNING:tensorflow:`period` argument is deprecated. Please use `save_freq` to specify the frequency in number of batches seen.
# Epoch 1/180
# 391/390 [==============================] - ETA: 0s - loss: 4.2666 - accuracy: 0.0364
# Epoch 00001: val_accuracy improved from -inf to 0.05550, saving model to Inception_Adam_dropout.hdf5
# 391/390 [==============================] - 30s 76ms/step - loss: 4.2666 - accuracy: 0.0364 - val_loss: 4.1876 - val_accuracy: 0.0555
# Epoch 2/180
# 391/390 [==============================] - ETA: 0s - loss: 3.8870 - accuracy: 0.0851
# Epoch 00002: val_accuracy improved from 0.05550 to 0.09540, saving model to Inception_Adam_dropout.hdf5
# 391/390 [==============================] - 29s 75ms/step - loss: 3.8870 - accuracy: 0.0851 - val_loss: 3.8963 - val_accuracy: 0.0954
# Epoch 3/180
# 391/390 [==============================] - ETA: 0s - loss: 3.6316 - accuracy: 0.1279
# Epoch 00003: val_accuracy improved from 0.09540 to 0.13410, saving model to Inception_Adam_dropout.hdf5
# 391/390 [==============================] -
saving model to Inception_Adam_dropout.hdf5
# 391/390 [==============================] - 29s 74ms/step - loss: 2.8073 - accuracy: 0.2845 - val_loss: 3.1848 - val_accuracy: 0.2859
# Epoch 16/180
# 391/390 [==============================] - ETA: 0s - loss: 2.7785 - accuracy: 0.2934
# Epoch 00016: val_accuracy improved from 0.28590 to 0.30560, saving model to Inception_Adam_dropout.hdf5
# 391/390 [==============================] - 29s 74ms/step - loss: 2.7785 - accuracy: 0.2934 - val_loss: 2.9053 - val_accuracy: 0.3056
# Epoch 17/180
# 391/390 [==============================] - ETA: 0s - loss: 2.7652 - accuracy: 0.2926
# Epoch 00017: val_accuracy did not improve from 0.30560
# 391/390 [==============================] - 29s 74ms/step - loss: 2.7652 - accuracy: 0.2926 - val_loss: 3.1429 - val_accuracy: 0.2998
# Epoch 18/180
# 391/390 [==============================] - ETA: 0s - loss: 2.7387 - accuracy: 0.2983
# Epoch 00018: val_accuracy did not improve from 0.30560
# 391/390 [==============================] - 29s 74ms/step - loss: 2.7387 - accuracy: 0.2983 - val_loss: 3.1389 - val_accuracy: 0.3013
# Epoch 19/180
# 391/390 [==============================] - ETA: 0s - loss: 2.7134 - accuracy: 0.3043
# Epoch 00019: val_accuracy did not improve from 0.30560
# 391/390 [==============================] - 28s 73ms/step - loss: 2.7134 - accuracy: 0.3043 - val_loss: 3.1090 - val_accuracy: 0.3019
# Epoch 20/180
# 391/390 [==============================] - ETA: 0s - loss: 2.6916 - accuracy: 0.3097
# Epoch 00020: val_accuracy improved from 0.30560 to 0.32240, saving model to Inception_Adam_dropout.hdf5
# 391/390 [==============================] - 29s 74ms/step - loss: 2.6916 - accuracy: 0.3097 - val_loss: 2.9817 - val_accuracy: 0.3224
# Epoch 21/180
# 391/390 [==============================] - ETA: 0s - loss: 2.6651 - accuracy: 0.3126
# Epoch 00021: val_accuracy did not improve from 0.32240
# 391/390 [==============================] - 29s 74ms/step - loss: 2.6651 - accuracy: 0.3126 - val_loss: 3.0462 - val_accuracy: 0.3139
# Epoch 22/180
# 391/390 [==============================] - ETA: 0s - loss: 2.6527 - accuracy: 0.3149
# Epoch 00022: val_accuracy did not improve from 0.32240
# 391/390 [==============================] - 29s 74ms/step - loss: 2.6527 - accuracy: 0.3149 - val_loss: 2.9238 - val_accuracy: 0.3212
# Epoch 23/180
# 391/390 [==============================] - ETA: 0s - loss: 2.6381 - accuracy: 0.3226
# Epoch 00023: val_accuracy improved from 0.32240 to 0.33610, saving model to Inception_Adam_dropout.hdf5
# 391/390 [==============================] - 29s 74ms/step - loss: 2.6381 - accuracy: 0.3226 - val_loss: 2.8820 - val_accuracy: 0.3361
# Epoch 24/180
# 391/390 [==============================] - ETA: 0s - loss: 2.6090 - accuracy: 0.3245
# Epoch 00024: val_accuracy did not improve from 0.33610
# 391/390 [==============================] - 29s 73ms/step - loss: 2.6090 - accuracy: 0.3245 - val_loss: 2.9755 - val_accuracy: 0.3348
# Epoch 25/180
# 391/390 [==============================] - ETA: 0s - loss: 2.5946 - accuracy: 0.3293
# 391/390 [==============================] - 28s 72ms/step - loss: 2.2319 - accuracy: 0.4051 - val_loss: 2.6144 - val_accuracy: 0.4208
# Epoch 68/180
# 391/390 [==============================] - ETA: 0s - loss: 2.2441 - accuracy: 0.4044
# Epoch 00068: val_accuracy did not improve from 0.42080
# 391/390 [==============================] - 28s 73ms/step - loss: 2.2441 - accuracy: 0.4044 - val_loss: 2.8227 - val_accuracy: 0.3995
# Epoch 69/180
# 391/390 [==============================] - ETA: 0s - loss: 2.2311 - accuracy: 0.4037
# Epoch 00069: val_accuracy did not improve from 0.42080
# 391/390 [==============================] - 28s 72ms/step - loss: 2.2311 - accuracy: 0.4037 - val_loss: 2.8183 - val_accuracy: 0.4050
# Epoch 70/180
# 391/390 [==============================] - ETA: 0s - loss: 2.2515 - accuracy: 0.4081
# Epoch 00070: val_accuracy did not improve from 0.42080
# 391/390 [==============================] - 28s 72ms/step - loss: 2.2515 - accuracy: 0.4081 - val_loss: 3.0933 - val_accuracy: 0.3836
# Epoch 71/180
# 391/390 [==============================] - ETA: 0s - loss: 2.2224 - accuracy: 0.4071
# Epoch 00071: val_accuracy did not improve from 0.42080
# 391/390 [==============================] - 28s 72ms/step - loss: 2.2224 - accuracy: 0.4071 - val_loss: 2.7026 - val_accuracy: 0.4066
# Epoch 72/180
# 391/390 [==============================] - ETA: 0s - loss: 2.2207 - accuracy: 0.4068Restoring model weights from the end of the best epoch.
#
# Epoch 00072: val_accuracy did not improve from 0.42080
# 391/390 [==============================] - 28s 72ms/step - loss: 2.2207 - accuracy: 0.4068 - val_loss: 2.7764 - val_accuracy: 0.4070
# Epoch 00072: early stopping

# %%
y_true = y_test.argmax(-1)
y_pred = model.predict(X_test).argmax(-1)


from sklearn.metrics import classification_report,accuracy_score,recall_score,precision_score
print(classification_report(Y_test,y_pred))
print("Accuracy is {}".format(accuracy_score(Y_test,y_pred)))
print("Precision is {}".format(precision_score(Y_test,y_pred,average="weighted")))
print("Recall is {}".format(recall_score(Y_test,y_pred,average="weighted")))
# Out:
#               precision    recall  f1-score   support
#
#            0       0.61      0.78      0.68       100
#            1       0.74      0.43      0.54       100
#            2       0.38      0.33      0.35       100
#            3       0.27      0.10      0.15       100
#            4       0.32      0.21      0.25       100
#            5       0.43      0.23      0.30       100
#            6       0.57      0.39      0.46       100
#            7       0.75      0.33      0.46       100
#            8       0.43      0.49      0.46       100
#            9       0.47      0.63      0.54       100
#           10       0.36      0.24      0.29       100
#           11       0.39      0.15      0.22       100
#           12       0.40      0.52      0.45       100
#           13       0.44      0.27      0.33       100
#           14       0.44      0.24      0.31       100
#           15       0.27      0.38      0.31       100
#           16       0.42      0.36      0.39       100
#           17       0.46      0.77      0.58       100
#           18       0.34      0.42      0.38       100
#           19       0.51      0.36      0.42       100
#           20       0.58      0.76      0.66       100
#           21       0.51      0.61      0.56       100
#           22       0.22      0.35      0.27       100
#           23       0.48      0.77      0.59       100
#           24       0.63      0.69      0.66       100
#           25       0.37      0.15      0.21       100
#           26       0.29      0.30      0.29       100
#           27       0.25      0.35      0.29       100
#           28       0.39      0.74      0.51       100
#           29       0.45      0.29      0.35       100
#           30       0.38      0.36      0.37       100
#           31       0.41      0.51      0.45       100
#           32       0.49      0.34      0.40       100
#           33       0.32      0.49      0.39       100
#           34       0.42      0.26      0.32       100
#           35       0.33      0.19      0.24       100
#           36       0.39      0.42      0.41       100
#           37       0.57      0.25      0.35       100
#           38       0.21      0.21      0.21       100
#           39       0.42      0.51      0.46       100
#           40       0.55      0.27      0.36       100
#           41       0.88      0.59      0.71       100
#           42       0.32      0.36      0.34       100
#           43       0.35      0.46      0.40       100
#           44       0.31      0.22      0.26       100
#           45       0.26      0.21      0.23       100
#           46       0.34      0.28      0.31       100
#           47       0.52      0.41      0.46       100
#           48       0.49      0.83      0.62       100
#           49       0.62      0.52      0.57       100
#           50       0.25      0.13      0.17       100
#           51       0.25      0.51      0.34       100
#           52       0.49      0.84      0.62       100
#           53       0.66      0.64      0.65       100
#           54       0.50      0.61      0.55       100
#           55       0.22      0.10      0.14       100
#           56       0.83      0.58      0.68       100
#           57       0.42      0.48      0.45       100
#           58       0.45      0.63      0.53       100
#           59       0.49      0.33      0.40       100
#           60       0.65      0.84      0.73       100
#           61       0.30      0.65      0.41       100
#           62       0.72      0.48      0.57       100
#           63       0.43      0.40      0.41       100
#           64       0.57      0.04      0.07       100
#           65       0.29      0.15      0.20       100
#           66       0.35      0.17      0.23       100
#           67       0.42      0.27      0.33       100
#           68       0.89      0.71      0.79       100
#           69       0.38      0.70      0.50       100
#           70       0.62      0.41      0.49       100
#           71       0.61      0.49      0.54       100
#           72       0.23      0.15      0.18       100
#           73       0.41      0.19      0.26       100
#           74       0.21      0.17      0.19       100
#           75       0.61      0.74      0.67       100
#           76       0.60      0.62      0.61       100
#           77       0.37      0.21      0.27       100
#           78       0.16      0.47      0.24       100
#           79       0.31      0.44      0.37       100
#           80       0.23      0.18      0.20       100
#           81       0.49      0.42      0.45       100
#           82       0.53      0.85      0.66       100
#           83       0.41      0.24      0.30       100
#           84       0.31      0.41      0.35       100
#           85       0.36      0.69      0.48       100
#           86       0.58      0.39      0.47       100
#           87       0.52      0.50      0.51       100
#           88       0.34      0.54      0.42       100
#           89       0.49      0.46      0.48       100
#           90       0.58      0.26      0.36       100
#           91       0.58      0.45      0.51       100
#           92       0.27      0.25      0.26       100
#           93       0.55      0.11      0.18       100
#           94       0.67      0.80      0.73       100
#           95       0.46      0.58      0.51       100
#           96       0.42      0.26      0.32       100
#           97       0.23      0.55      0.33       100
#           98       0.20      0.05      0.08       100
#           99       0.31      0.60      0.41       100
#
#     accuracy                           0.42     10000
#    macro avg       0.44      0.42      0.41     10000
# weighted avg       0.44      0.42      0.41     10000
#
# Accuracy is 0.4207
# Precision is 0.43963989639456486
# Recall is 0.4207

# %%
y_true1 = y_test.argmax(-1)
yy_pred = model.predict(X_train).argmax(-1)
print("Accuracy is {}".format(accuracy_score(Y_train,yy_pred)))
# Out:
# Accuracy is 0.47668

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
from tensorflow.keras.models import Sequential,Model
from tensorflow.keras.layers import Dense,Flatten,Input,Conv2D,MaxPool2D,concatenate,BatchNormalization,Dropout
from keras.layers.convolutional import MaxPooling2D
from keras.layers.merge import concatenate
from keras.layers import Concatenate, Dense, LSTM, Input, concatenate
from keras.layers import Conv2D

from tensorflow.keras import layers

import tensorflow.keras as keras

import tensorflow.keras as keras

from tensorflow.keras.preprocessing.image import ImageDataGenerator

from tensorflow.keras.layers import LeakyReLU

from tensorflow.keras.datasets import cifar100
from tensorflow.keras.utils import to_categorical

from tensorflow.keras.callbacks import EarlyStopping,ModelCheckpoint

from keras.optimizers import Adam,SGD


(X_train,Y_train),(X_test,Y_test)=cifar100.load_data()
y_train,y_test=to_categorical(Y_train),to_categorical(Y_test)
X_train,X_test=X_train/255,X_test/255



inputs=keras.Input(shape=(32,32,3))

a=layers.Conv2D(filters=32,kernel_size=(3,3),padding="same",strides=2,activation=LeakyReLU(alpha=0.1))(inputs)
a=layers.Dropout(0.05)(a)


a=layers.Conv2D(filters=32,kernel_size=(3,3),padding="same",strides=1,activation=LeakyReLU(alpha=0.1))(a)
a=layers.Dropout(0.05)(a)



a=layers.Conv2D(filters=32, kernel_size=(3,3), padding="same",strides=1,activation=LeakyReLU(alpha=0.1))(a)
a=layers.Dropout(0.05)(a)


a=layers.MaxPool2D(pool_size=(3,3),strides=(2,2))(a)


a=layers.Conv2D(filters=32, kernel_size=(3,3), padding="same",strides=1,activation=LeakyReLU(alpha=0.1))(a)
a=layers.Dropout(0.05)(a)



a=layers.Conv2D(filters=32, kernel_size=(3,3), padding="same",strides=2,activation=LeakyReLU(alpha=0.1))(a)
a=layers.Dropout(0.05)(a)



a=layers.Conv2D(filters=32, kernel_size=(3,3), padding="same",strides=1,activation=LeakyReLU(alpha=0.1))(a)
a=layers.Dropout(0.05)(a)



#inception-1
b=layers.Conv2D(64, (1,1), padding='same',strides=1,activation=LeakyReLU(alpha=0.1))(a)
b=layers.Dropout(0.05)(b)


b=layers.Conv2D(64, (3,3), padding='same',strides=1 ,activation=LeakyReLU(alpha=0.1))(b)
b=layers.Dropout(0.05)(b)


b=layers.Conv2D(64, (3,3), padding='same', strides=1,activation=LeakyReLU(alpha=0.1))(b)
b=layers.Dropout(0.05)(b)


c=layers.Conv2D(64, (1,1), padding='same', strides=1, activation=LeakyReLU(alpha=0.1))(a)
c=layers.Dropout(0.05)(c)

c=layers.Conv2D(64, (3,3), padding='same', strides=1, activation=LeakyReLU(alpha=0.1))(c)
c=layers.Dropout(0.05)(c)


d=layers.MaxPooling2D((3,3), strides=(1,1), padding='same')(a)
d=layers.Dropout(0.05)(d)

d=layers.Conv2D(64, (1,1), padding='same', strides=1, activation=LeakyReLU(alpha=0.1))(d)
d=layers.Dropout(0.05)(d)


e=layers.Conv2D(64, (1,1), padding='same', strides=1, activation=LeakyReLU(alpha=0.1))(a)
e=layers.Dropout(0.05)(e)


a=layers.concatenate([b, c, d,e],axis=3)
#a=Dropout(0.05)(a)


#inception-2
f=layers.Conv2D(128, (1,1), padding='same', strides=1, activation=LeakyReLU(alpha=0.1))(a)
f=layers.Dropout(0.05)(f)

f=layers.Conv2D(128, (1,7), padding='same', strides=1, activation=LeakyReLU(alpha=0.1))(f)
f=layers.Dropout(0.05)(f)


f=layers.Conv2D(128, (7,1), padding='same', strides=1, activation=LeakyReLU(alpha=0.1))(f)
f=layers.Dropout(0.05)(f)

f=layers.Conv2D(128, (1,7), padding='same', strides=1, activation=LeakyReLU(alpha=0.1))(f)
f=layers.Dropout(0.05)(f)


f=layers.Conv2D(128, (7,1), padding='same', strides=1, activation=LeakyReLU(alpha=0.1))(f)
f=layers.Dropout(0.05)(f)


g=layers.Conv2D(128, (1,1), padding='same', strides=1, activation=LeakyReLU(alpha=0.1))(a)
g=layers.Dropout(0.05)(g)

g=layers.Conv2D(128, (1,7), padding='same', strides=1,activation=LeakyReLU(alpha=0.1))(g)
g=layers.Dropout(0.05)(g)


g=layers.Conv2D(128, (7,1), padding='same', strides=1, activation=LeakyReLU(alpha=0.1))(g)

g=layers.Dropout(0.05)(g)


h=layers.MaxPooling2D((3,3), strides=(1,1), padding='same')(a)
h=layers.Dropout(0.05)(h)

h=layers.Conv2D(128, (1,1), padding='same', strides=1, activation=LeakyReLU(alpha=0.1))(h)
h=layers.Dropout(0.05)(h)


i=layers.Conv2D(128, (1,1), padding='same', strides=1, activation=LeakyReLU(alpha=0.1))(h)
i=layers.Dropout(0.05)(i)


a=layers.concatenate([f,g,h,i],axis=3)
#a=Dropout(0.05)(a)

#inception-3
j=layers.Conv2D(256, (1,1), padding='same', strides=1, activation=LeakyReLU(alpha=0.1))(a)
j=layers.Dropout(0.05)(j)


j=layers.Conv2D(256, (3,3), padding='same', strides=1, activation=LeakyReLU(alpha=0.1))(j)
j=layers.Dropout(0.05)(j)

k=layers.Conv2D(256, (1,3), padding='same', strides=1, activation=LeakyReLU(alpha=0.1))(j)
#k=Dropout(0.05)(k)

l=layers.Conv2D(256, (3,1), padding='same', strides=1, activation=LeakyReLU(alpha=0.1))(j)
#l=Dropout(0.05)(l)


m=layers.Conv2D(256, (1,1), padding='same', activation=LeakyReLU(alpha=0.1))(a)
m=layers.Dropout(0.05)(m)

n=layers.Conv2D(256, (1,3), padding='same', activation=LeakyReLU(alpha=0.1))(m)
#n=Dropout(0.05)(n)

o=layers.Conv2D(256, (3,1), padding='same', activation=LeakyReLU(alpha=0.1))(m)
#o=Dropout(0.05)(o)


p=layers.MaxPool2D((3,3), strides=(1,1), padding='same')(a)
p=layers.Conv2D(256, (1,1), padding='same', strides=1, activation=LeakyReLU(alpha=0.1))(p)
p=layers.Dropout(0.05)(p)


q=layers.Conv2D(256, (1,1), padding='same', strides=1, activation=LeakyReLU(alpha=0.1))(a)
q=layers.Dropout(0.05)(q)


a=layers.concatenate([k,l,n,o,p,q],axis=3)
a=layers.Dropout(0.05)(a)


a=layers.MaxPooling2D((8,8), strides=(1,1), padding='same')(a)
#a=Dropout(0.05)(a)


a=layers.Flatten()(a)

a=layers.Dense(units=256,activation=LeakyReLU(alpha=0.1))(a)
a=layers.Dropout(0.05)(a)


outputs=layers.Dense(y_train.shape[1],activation="softmax")(a)

model=keras.Model(inputs,outputs)

model.load_weights("../weights/Inception_Adam_dropout.hdf5")

y_true = y_test.argmax(-1)
y_pred = model.predict(X_test).argmax(-1)


from sklearn.metrics import classification_report,accuracy_score,recall_score,precision_score
print(classification_report(Y_test,y_pred))
print("Accuracy is {}".format(accuracy_score(Y_test,y_pred)))
print("Precision is {}".format(precision_score(Y_test,y_pred,average="weighted")))
print("Recall is {}".format(recall_score(Y_test,y_pred,average="weighted")))
# Out:
#               precision    recall  f1-score   support
#
#            0       0.45      0.86      0.59       100
#            1       0.78      0.39      0.52       100
#            2       0.36      0.51      0.42       100
#            3       0.27      0.18      0.22       100
#            4       0.24      0.10      0.14       100
#            5       0.40      0.33      0.36       100
#            6       0.54      0.40      0.46       100
#            7       0.69      0.29      0.41       100
#            8       0.49      0.53      0.51       100
#            9       0.55      0.66      0.60       100
#           10       0.32      0.23      0.27       100
#           11       0.42      0.18      0.25       100
#           12       0.56      0.34      0.42       100
#           13       0.41      0.20      0.27       100
#           14       0.54      0.25      0.34       100
#           15       0.27      0.40      0.32       100
#           16       0.38      0.43      0.41       100
#           17       0.57      0.73      0.64       100
#           18       0.43      0.26      0.33       100
#           19       0.46      0.30      0.36       100
#           20       0.76      0.65      0.70       100
#           21       0.54      0.68      0.60       100
#           22       0.29      0.16      0.21       100
#           23       0.66      0.64      0.65       100
#           24       0.47      0.68      0.56       100
#           25       0.37      0.21      0.27       100
#           26       0.31      0.41      0.35       100
#           27       0.32      0.29      0.30       100
#           28       0.47      0.65      0.54       100
#           29       0.56      0.23      0.33       100
#           30       0.41      0.46      0.43       100
#           31       0.34      0.52      0.41       100
#           32       0.52      0.32      0.40       100
#           33       0.32      0.51      0.40       100
#           34       0.41      0.49      0.45       100
#           35       0.27      0.15      0.19       100
#           36       0.44      0.32      0.37       100
#           37       0.39      0.39      0.39       100
#           38       0.36      0.14      0.20       100
#           39       0.57      0.43      0.49       100
#           40       0.41      0.28      0.33       100
#           41       0.95      0.56      0.70       100
#           42       0.36      0.31      0.33       100
#           43       0.34      0.54      0.41       100
#           44       0.33      0.16      0.21       100
#           45       0.47      0.17      0.25       100
#           46       0.45      0.14      0.21       100
#           47       0.49      0.44      0.47       100
#           48       0.49      0.81      0.61       100
#           49       0.60      0.60      0.60       100
#           50       0.26      0.18      0.21       100
#           51       0.25      0.52      0.34       100
#           52       0.40      0.86      0.55       100
#           53       0.55      0.80      0.65       100
#           54       0.47      0.63      0.54       100
#           55       0.21      0.16      0.18       100
#           56       0.68      0.68      0.68       100
#           57       0.47      0.38      0.42       100
#           58       0.38      0.56      0.46       100
#           59       0.34      0.27      0.30       100
#           60       0.59      0.89      0.71       100
#           61       0.28      0.80      0.41       100
#           62       0.54      0.37      0.44       100
#           63       0.41      0.32      0.36       100
#           64       0.42      0.19      0.26       100
#           65       0.18      0.12      0.14       100
#           66       0.47      0.14      0.22       100
#           67       0.34      0.38      0.36       100
#           68       0.81      0.81      0.81       100
#           69       0.71      0.52      0.60       100
#           70       0.38      0.61      0.47       100
#           71       0.62      0.61      0.62       100
#           72       0.27      0.08      0.12       100
#           73       0.40      0.23      0.29       100
#           74       0.27      0.22      0.24       100
#           75       0.61      0.70      0.65       100
#           76       0.67      0.64      0.65       100
#           77       0.32      0.36      0.34       100
#           78       0.15      0.49      0.23       100
#           79       0.24      0.51      0.32       100
#           80       0.16      0.10      0.12       100
#           81       0.43      0.42      0.43       100
#           82       0.78      0.73      0.75       100
#           83       0.48      0.11      0.18       100
#           84       0.32      0.42      0.36       100
#           85       0.39      0.57      0.46       100
#           86       0.63      0.27      0.38       100
#           87       0.52      0.45      0.48       100
#           88       0.44      0.52      0.47       100
#           89       0.56      0.50      0.53       100
#           90       0.66      0.27      0.38       100
#           91       0.56      0.43      0.49       100
#           92       0.36      0.29      0.32       100
#           93       0.26      0.14      0.18       100
#           94       0.44      0.91      0.60       100
#           95       0.48      0.52      0.50       100
#           96       0.41      0.24      0.30       100
#           97       0.42      0.48      0.45       100
#           98       0.29      0.16      0.21       100
#           99       0.22      0.61      0.33       100
#
#     accuracy                           0.42     10000
#    macro avg       0.44      0.42      0.41     10000
# weighted avg       0.44      0.42      0.41     10000
#
# Accuracy is 0.4208
# Precision is 0.4424999840313765
# Recall is 0.4208
