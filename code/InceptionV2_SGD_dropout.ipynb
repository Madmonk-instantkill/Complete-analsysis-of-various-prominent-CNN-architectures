# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
from tensorflow.keras.models import Sequential,Model
from tensorflow.keras.layers import Dense,Flatten,Input,Conv2D,MaxPool2D,concatenate,BatchNormalization,Dropout
from keras.layers.convolutional import MaxPooling2D
from keras.layers.merge import concatenate
from keras.layers import Concatenate, Dense, LSTM, Input, concatenate
from keras.layers import Conv2D

from tensorflow.keras import layers

import tensorflow.keras as keras

import tensorflow.keras as keras

from tensorflow.keras.preprocessing.image import ImageDataGenerator

from tensorflow.keras.layers import LeakyReLU

from tensorflow.keras.datasets import cifar100
from tensorflow.keras.utils import to_categorical

from tensorflow.keras.callbacks import EarlyStopping,ModelCheckpoint

from keras.optimizers import Adam,SGD
# Out:
# Using TensorFlow backend.

# %%
(X_train,Y_train),(X_test,Y_test)=cifar100.load_data()
y_train,y_test=to_categorical(Y_train),to_categorical(Y_test)
X_train,X_test=X_train/255,X_test/255

aug_data=ImageDataGenerator(rotation_range=15,horizontal_flip=True,width_shift_range=0.1,height_shift_range=0.1,zoom_range=0.3)
aug_data.fit(X_train)

# %%
inputs=keras.Input(shape=(32,32,3))

a=Conv2D(filters=32,kernel_size=(3,3),padding="same",strides=2,activation=LeakyReLU(alpha=0.1))(inputs)
a=Dropout(0.01)(a)


a=Conv2D(filters=32,kernel_size=(3,3),padding="same",strides=1,activation=LeakyReLU(alpha=0.1))(a)
a=Dropout(0.01)(a)



a=Conv2D(filters=32, kernel_size=(3,3), padding="same",strides=1,activation=LeakyReLU(alpha=0.1))(a)
a=Dropout(0.01)(a)


a=(MaxPool2D(pool_size=(3,3),strides=(2,2)))(a)


a=Conv2D(filters=32, kernel_size=(3,3), padding="same",strides=1,activation=LeakyReLU(alpha=0.1))(a)
a=Dropout(0.01)(a)



a=Conv2D(filters=32, kernel_size=(3,3), padding="same",strides=2,activation=LeakyReLU(alpha=0.1))(a)
a=Dropout(0.01)(a)



a=Conv2D(filters=32, kernel_size=(3,3), padding="same",strides=1,activation=LeakyReLU(alpha=0.1))(a)
a=Dropout(0.01)(a)



#inception-1
b=Conv2D(64, (1,1), padding='same',strides=1,activation=LeakyReLU(alpha=0.1))(a)
b=Dropout(0.01)(b)


b=Conv2D(64, (3,3), padding='same',strides=1 ,activation=LeakyReLU(alpha=0.1))(b)
b=Dropout(0.01)(b)


b=Conv2D(64, (3,3), padding='same', strides=1,activation=LeakyReLU(alpha=0.1))(b)
b=Dropout(0.01)(b)


c=Conv2D(64, (1,1), padding='same', strides=1, activation=LeakyReLU(alpha=0.1))(a)
c=Dropout(0.01)(c)

c=Conv2D(64, (3,3), padding='same', strides=1, activation=LeakyReLU(alpha=0.1))(c)
c=Dropout(0.01)(c)


d=MaxPooling2D((3,3), strides=(1,1), padding='same')(a)
d=Dropout(0.01)(d)

d=Conv2D(64, (1,1), padding='same', strides=1, activation=LeakyReLU(alpha=0.1))(d)
d=Dropout(0.01)(d)


e=Conv2D(64, (1,1), padding='same', strides=1, activation=LeakyReLU(alpha=0.1))(a)
e=Dropout(0.01)(e)


a=concatenate([b, c, d,e],axis=3)
#a=Dropout(0.01)(a)


#inception-2
f=Conv2D(128, (1,1), padding='same', strides=1, activation=LeakyReLU(alpha=0.1))(a)
f=Dropout(0.01)(f)

f=Conv2D(128, (1,7), padding='same', strides=1, activation=LeakyReLU(alpha=0.1))(f)
f=Dropout(0.01)(f)


f=Conv2D(128, (7,1), padding='same', strides=1, activation=LeakyReLU(alpha=0.1))(f)
f=Dropout(0.01)(f)

f=Conv2D(128, (1,7), padding='same', strides=1, activation=LeakyReLU(alpha=0.1))(f)
f=Dropout(0.01)(f)


f=Conv2D(128, (7,1), padding='same', strides=1, activation=LeakyReLU(alpha=0.1))(f)
f=Dropout(0.01)(f)


g=Conv2D(128, (1,1), padding='same', strides=1, activation=LeakyReLU(alpha=0.1))(a)
g=Dropout(0.01)(g)

g=Conv2D(128, (1,7), padding='same', strides=1,activation=LeakyReLU(alpha=0.1))(g)
g=Dropout(0.01)(g)


g=Conv2D(128, (7,1), padding='same', strides=1, activation=LeakyReLU(alpha=0.1))(g)

g=Dropout(0.01)(g)


h=MaxPooling2D((3,3), strides=(1,1), padding='same')(a)
h=Dropout(0.01)(h)

h=Conv2D(128, (1,1), padding='same', strides=1, activation=LeakyReLU(alpha=0.1))(h)
h=Dropout(0.01)(h)


i=Conv2D(128, (1,1), padding='same', strides=1, activation=LeakyReLU(alpha=0.1))(h)
i=Dropout(0.01)(i)


a=concatenate([f,g,h,i],axis=3)
#a=Dropout(0.01)(a)

#inception-3
j=Conv2D(256, (1,1), padding='same', strides=1, activation=LeakyReLU(alpha=0.1))(a)
j=Dropout(0.01)(j)


j=Conv2D(256, (3,3), padding='same', strides=1, activation=LeakyReLU(alpha=0.1))(j)
j=Dropout(0.01)(j)

k=Conv2D(256, (1,3), padding='same', strides=1, activation=LeakyReLU(alpha=0.1))(j)
#k=Dropout(0.01)(k)

l=Conv2D(256, (3,1), padding='same', strides=1, activation=LeakyReLU(alpha=0.1))(j)
#l=Dropout(0.01)(l)


m=Conv2D(256, (1,1), padding='same', activation=LeakyReLU(alpha=0.1))(a)
m=Dropout(0.01)(m)

n=Conv2D(256, (1,3), padding='same', activation=LeakyReLU(alpha=0.1))(m)
#n=Dropout(0.01)(n)

o=Conv2D(256, (3,1), padding='same', activation=LeakyReLU(alpha=0.1))(m)
#o=Dropout(0.01)(o)


p=MaxPool2D((3,3), strides=(1,1), padding='same')(a)
p=Conv2D(256, (1,1), padding='same', strides=1, activation=LeakyReLU(alpha=0.1))(p)
p=Dropout(0.01)(p)


q=Conv2D(256, (1,1), padding='same', strides=1, activation=LeakyReLU(alpha=0.1))(a)
q=Dropout(0.01)(q)


a=concatenate([k,l,n,o,p,q],axis=3)
a=Dropout(0.01)(a)


a=MaxPooling2D((8,8), strides=(1,1), padding='same')(a)
#a=Dropout(0.01)(a)


a=Flatten()(a)

a=Dense(units=256,activation=LeakyReLU(alpha=0.1))(a)
a=Dropout(0.01)(a)


outputs=Dense(y_train.shape[1],activation="softmax")(a)

model=keras.Model(inputs,outputs)

#adam=Adam(learning_rate=0.001,clipnorm=0.7)

sgd=SGD(learning_rate=0.01,momentum=0.9,clipnorm=1)


model.compile(loss="categorical_crossentropy",optimizer=sgd,metrics=['accuracy'])


# call=EarlyStopping(monitor="val_loss",verbose=1,mode="auto",patience=10,restore_best_weights="true")

# checkpoint=ModelCheckpoint('Inception_SGD_dropout.hdf5',monitor='val_accuracy',verbose=1,save_best_only=True,save_weights_only=True,model='auto',period=1)
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-5-26633890c14c> in <module>
#       1 inputs=keras.Input(shape=(32,32,3))
#       2
# ----> 3 a=Conv2D(filters=32,kernel_size=(3,3),padding="same",strides=2,activation=LeakyReLU(alpha=0.1))(inputs)
#       4 a=Dropout(0.01)(a)
#       5
#
# C:\anaconda3\envs\cse676\lib\site-packages\keras\engine\base_layer.py in __call__(self, inputs, **kwargs)
#     441
#     442             # Handle mask propagation.
# --> 443             previous_mask = _collect_previous_mask(inputs)
#     444             user_kwargs = copy.copy(kwargs)
#     445             if not is_all_none(previous_mask):
#
# C:\anaconda3\envs\cse676\lib\site-packages\keras\engine\base_layer.py in _collect_previous_mask(input_tensors)
#    1309             inbound_layer, node_index, tensor_index = x._keras_history
#    1310             node = inbound_layer._inbound_nodes[node_index]
# -> 1311             mask = node.output_masks[tensor_index]
#    1312             masks.append(mask)
#    1313         else:
#
# AttributeError: 'Node' object has no attribute 'output_masks'

# %%
model.fit_generator(aug_data.flow(X_train,y_train,batch_size=128),steps_per_epoch=len(X_train)/128,epochs=180,validation_data=(X_test,y_test),verbose=1,callbacks=[call,checkpoint])
# Out:
# Epoch 1/180
# 391/390 [==============================] - ETA: 0s - loss: 4.6002 - accuracy: 0.0130
# Epoch 00001: val_accuracy improved from -inf to 0.01950, saving model to Inception_SGD_dropout.hdf5
# 391/390 [==============================] - 30s 76ms/step - loss: 4.6002 - accuracy: 0.0130 - val_loss: 4.5545 - val_accuracy: 0.0195
# Epoch 2/180
# 391/390 [==============================] - ETA: 0s - loss: 4.3210 - accuracy: 0.0367
# Epoch 00002: val_accuracy improved from 0.01950 to 0.05910, saving model to Inception_SGD_dropout.hdf5
# 391/390 [==============================] - 30s 76ms/step - loss: 4.3210 - accuracy: 0.0367 - val_loss: 4.1194 - val_accuracy: 0.0591
# Epoch 3/180
# 391/390 [==============================] - ETA: 0s - loss: 4.0032 - accuracy: 0.0746
# Epoch 00003: val_accuracy improved from 0.05910 to 0.08320, saving model to Inception_SGD_dropout.hdf5
# 391/390 [==============================] - 30s 77ms/step - loss: 4.0032 - accuracy: 0.0746 - val_loss: 3.9187 - val_accuracy: 0.0832
# Epoch 4/180
# 391/390 [==============================] - ETA: 0s - loss: 3.7923 - accuracy: 0.1076
# Epoch 00004: val_accuracy improved from 0.08320 to 0.13900, saving model to Inception_SGD_dropout.hdf5
# 391/390 [==============================] - 30s 77ms/step - loss: 3.7923 - accuracy: 0.1076 - val_loss: 3.5925 - val_accuracy: 0.1390
# Epoch 5/180
# 391/390 [==============================] - ETA: 0s - loss: 3.6056 - accuracy: 0.1401
# Epoch 00005: val_accuracy improved from 0.13900 to 0.17790, saving model to Inception_SGD_dropout.hdf5
# 391/390 [==============================] - 30s 77ms/step - loss: 3.6056 - accuracy: 0.1401 - val_loss: 3.4402 - val_accuracy: 0.1779
# Epoch 6/180
# 391/390 [==============================] - ETA: 0s - loss: 3.4546 - accuracy: 0.1675
# Epoch 00006: val_accuracy improved from 0.17790 to 0.20000, saving model to Inception_SGD_dropout.hdf5
# 391/390 [==============================] - 30s 78ms/step - loss: 3.4546 - accuracy: 0.1675 - val_loss: 3.2855 - val_accuracy: 0.2000
# Epoch 7/180
# 391/390 [==============================] - ETA: 0s - loss: 3.3323 - accuracy: 0.1884
# Epoch 00007: val_accuracy improved from 0.20000 to 0.22950, saving model to Inception_SGD_dropout.hdf5
# 391/390 [==============================] - 31s 78ms/step - loss: 3.3323 - accuracy: 0.1884 - val_loss: 3.1618 - val_accuracy: 0.2295
# Epoch 8/180
# 391/390 [==============================] - ETA: 0s - loss: 3.2392 - accuracy: 0.2052
# Epoch 00008: val_accuracy improved from 0.22950 to 0.23220, saving model to Inception_SGD_dropout.hdf5
# 391/390 [==============================] - 31s 78ms/step - loss: 3.2392 - accuracy: 0.2052 - val_loss: 3.1197 - val_accuracy: 0.2322
# Epoch 9/180
# 391/390 [==============================] - ETA: 0s - loss: 3.1512 - accuracy: 0.2223
# Epoch 00009: val_accuracy improved from 0.23220 to 0.25370, saving model to Inception_SGD_dropout.hdf5
# 391/390 [==============================] - 30s 77ms/step - loss: 3.1512 - accuracy: 0.2223 - val_loss: 3.0015 - val_accuracy: 0.2537
# Epoch 10/180
# 391/390 [==============================] - ETA: 0s - loss: 3.0670 - accuracy: 0.2388
# Epoch 00010: val_accuracy improved from 0.25370 to 0.26420, saving model to Inception_SGD_dropout.hdf5
# 391/390 [==============================] -
)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-7-7390aea28ab7> in <module>
#       1 y_true = y_test.argmax(-1)
# ----> 2 y_pred = model.predict(X_test).argmax(-1)
#
# NameError: name 'model' is not defined

# %%
from sklearn.metrics import classification_report,accuracy_score,recall_score,precision_score
print(classification_report(Y_test,y_pred))
print("Accuracy is {}".format(accuracy_score(Y_test,y_pred)))
print("Precision is {}".format(precision_score(Y_test,y_pred,average="weighted")))
print("Recall is {}".format(recall_score(Y_test,y_pred,average="weighted")))
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-6-7524c7ef7a9b> in <module>
#       1 from sklearn.metrics import classification_report,accuracy_score,recall_score,precision_score
# ----> 2 print(classification_report(Y_test,y_pred))
#       3 print("Accuracy is {}".format(accuracy_score(Y_test,y_pred)))
#       4 print("Precision is {}".format(precision_score(Y_test,y_pred,average="weighted")))
#       5 print("Recall is {}".format(recall_score(Y_test,y_pred,average="weighted")))
#
# NameError: name 'y_pred' is not defined

# %%
model.summary()
# Out:
# Model: "functional_3"
# __________________________________________________________________________________________________
# Layer (type)                    Output Shape         Param #     Connected to
# ==================================================================================================
# input_2 (InputLayer)            [(None, 32, 32, 3)]  0
# __________________________________________________________________________________________________
# conv2d_32 (Conv2D)              (None, 16, 16, 32)   896         input_2[0][0]
# __________________________________________________________________________________________________
# dropout_32 (Dropout)            (None, 16, 16, 32)   0           conv2d_32[0][0]
# __________________________________________________________________________________________________
# conv2d_33 (Conv2D)              (None, 16, 16, 32)   9248        dropout_32[0][0]
# __________________________________________________________________________________________________
# dropout_33 (Dropout)            (None, 16, 16, 32)   0           conv2d_33[0][0]
# __________________________________________________________________________________________________
# conv2d_34 (Conv2D)              (None, 16, 16, 32)   9248        dropout_33[0][0]
# __________________________________________________________________________________________________
# dropout_34 (Dropout)            (None, 16, 16, 32)   0           conv2d_34[0][0]
# __________________________________________________________________________________________________
# max_pooling2d_5 (MaxPooling2D)  (None, 7, 7, 32)     0           dropout_34[0][0]
# __________________________________________________________________________________________________
# conv2d_35 (Conv2D)              (None, 7, 7, 32)     9248        max_pooling2d_5[0][0]
# __________________________________________________________________________________________________
# dropout_35 (Dropout)            (None, 7, 7, 32)     0           conv2d_35[0][0]
# __________________________________________________________________________________________________
# conv2d_36 (Conv2D)              (None, 4, 4, 32)     9248        dropout_35[0][0]
# __________________________________________________________________________________________________
# dropout_36 (Dropout)            (None, 4, 4, 32)     0           conv2d_36[0][0]
# __________________________________________________________________________________________________
# conv2d_37 (Conv2D)              (None, 4, 4, 32)     9248        dropout_36[0][0]
# __________________________________________________________________________________________________
# dropout_37 (Dropout)            (None, 4, 4, 32)     0           conv2d_37[0][0]
# __________________________________________________________________________________________________
# conv2d_38 (Conv2D)              (None, 4, 4, 64)     2112        dropout_37[0][0]
# __________________________________________________________________________________________________
# dropout_38 (Dropout)            (None, 4, 4, 64)     0           conv2d_38[0][0]
# __________________________________________________________________________________________________
# conv2d_39 (Conv2D)              (None, 4, 4, 64)     36928       dropout_38[0][0]
# __________________________________________________________________________________________________
# conv2d_41 (Conv2D)              (None, 4, 4, 64)     2112        dropout_37[0][0]
# __________________________________________________________________________________________________
# max_pooling2d_6 (MaxPooling2D)  (None, 4, 4, 32)     0           dropout_37[0][0]
# __________________________________________________________________________________________________
# dropout_39 (Dropout)            (None, 4, 4, 64)     0           conv2d_39[0][0]
# __________________________________________________________________________________________________
# dropout_41 (Dropout)            (None, 4, 4, 64)     0           conv2d_41[0][0]
# __________________________________________________________________________________________________
# dropout_43 (Dropout)            (None, 4, 4, 32)     0           max_pooling2d_6[0][0]
# __________________________________________________________________________________________________
# conv2d_40 (Conv2D)              (None, 4, 4, 64)     36928       dropout_39[0][0]
# __________________________________________________________________________________________________
# conv2d_42 (Conv2D)              (None, 4, 4, 64)     36928       dropout_41[0][0]
# __________________________________________________________________________________________________
# conv2d_43 (Conv2D)              (None, 4, 4, 64)     2112        dropout_43[0][0]
# __________________________________________________________________________________________________
# conv2d_44 (Conv2D)              (None, 4, 4, 64)     2112        dropout_37[0][0]
# __________________________________________________________________________________________________
# dropout_40 (Dropout)            (None, 4, 4, 64)     0           conv2d_40[0][0]
# __________________________________________________________________________________________________
# dropout_42 (Dropout)            (None, 4, 4, 64)     0           conv2d_42[0][0]
# __________________________________________________________________________________________________
# dropout_44 (Dropout)            (None, 4, 4, 64)     0           conv2d_43[0][0]
# __________________________________________________________________________________________________
# dropout_45 (Dropout)            (None, 4, 4, 64)     0           conv2d_44[0][0]
# __________________________________________________________________________________________________
# concatenate_3 (Concatenate)     (None, 4, 4, 256)    0           dropout_40[0][0]
#                                                                  dropout_42[0][0]
#                                                                  dropout_44[0][0]
#                                                                  dropout_45[0][0]
# __________________________________________________________________________________________________
# conv2d_45 (Conv2D)              (None, 4, 4, 128)    32896       concatenate_3[0][0]
# __________________________________________________________________________________________________
# dropout_46 (Dropout)            (None, 4, 4, 128)    0           conv2d_45[0][0]
# __________________________________________________________________________________________________
# conv2d_46 (Conv2D)              (None, 4, 4, 128)    114816      dropout_46[0][0]
# __________________________________________________________________________________________________
# dropout_47 (Dropout)            (None, 4, 4, 128)    0           conv2d_46[0][0]
# __________________________________________________________________________________________________
# conv2d_47 (Conv2D)              (None, 4, 4, 128)    114816      dropout_47[0][0]
# __________________________________________________________________________________________________
# conv2d_50 (Conv2D)              (None, 4, 4, 128)    32896       concatenate_3[0][0]
# __________________________________________________________________________________________________
# max_pooling2d_7 (MaxPooling2D)  (None, 4, 4, 256)    0           concatenate_3[0][0]
# __________________________________________________________________________________________________
# dropout_48 (Dropout)            (None, 4, 4, 128)    0           conv2d_47[0][0]
# __________________________________________________________________________________________________
# dropout_51 (Dropout)            (None, 4, 4, 128)    0           conv2d_50[0][0]
# __________________________________________________________________________________________________
# dropout_54 (Dropout)            (None, 4, 4, 256)    0           max_pooling2d_7[0][0]
# __________________________________________________________________________________________________
# conv2d_48 (Conv2D)              (None, 4, 4, 128)    114816      dropout_48[0][0]
# __________________________________________________________________________________________________
# conv2d_51 (Conv2D)              (None, 4, 4, 128)    114816      dropout_51[0][0]
# __________________________________________________________________________________________________
# conv2d_53 (Conv2D)              (None, 4, 4, 128)    32896       dropout_54[0][0]
# __________________________________________________________________________________________________
# dropout_49 (Dropout)            (None, 4, 4, 128)    0           conv2d_48[0][0]
# __________________________________________________________________________________________________
# dropout_52 (Dropout)            (None, 4, 4, 128)    0           conv2d_51[0][0]
# __________________________________________________________________________________________________
# dropout_55 (Dropout)            (None, 4, 4, 128)    0           conv2d_53[0][0]
# __________________________________________________________________________________________________
# conv2d_49 (Conv2D)              (None, 4, 4, 128)    114816      dropout_49[0][0]
# __________________________________________________________________________________________________
# conv2d_52 (Conv2D)              (None, 4, 4, 128)    114816      dropout_52[0][0]
# __________________________________________________________________________________________________
# conv2d_54 (Conv2D)              (None, 4, 4, 128)    16512       dropout_55[0][0]
# __________________________________________________________________________________________________
# dropout_50 (Dropout)            (None, 4, 4, 128)    0           conv2d_49[0][0]
# __________________________________________________________________________________________________
# dropout_53 (Dropout)            (None, 4, 4, 128)    0           conv2d_52[0][0]
# __________________________________________________________________________________________________
# dropout_56 (Dropout)            (None, 4, 4, 128)    0           conv2d_54[0][0]
# __________________________________________________________________________________________________
# concatenate_4 (Concatenate)     (None, 4, 4, 512)    0           dropout_50[0][0]
#                                                                  dropout_53[0][0]
#                                                                  dropout_55[0][0]
#                                                                  dropout_56[0][0]
# __________________________________________________________________________________________________
# conv2d_55 (Conv2D)              (None, 4, 4, 256)    131328      concatenate_4[0][0]
# __________________________________________________________________________________________________
# dropout_57 (Dropout)            (None, 4, 4, 256)    0           conv2d_55[0][0]
# __________________________________________________________________________________________________
# conv2d_56 (Conv2D)              (None, 4, 4, 256)    590080      dropout_57[0][0]
# __________________________________________________________________________________________________
# conv2d_59 (Conv2D)              (None, 4, 4, 256)    131328      concatenate_4[0][0]
# __________________________________________________________________________________________________
# max_pooling2d_8 (MaxPooling2D)  (None, 4, 4, 512)    0           concatenate_4[0][0]
# __________________________________________________________________________________________________
# dropout_58 (Dropout)            (None, 4, 4, 256)    0           conv2d_56[0][0]
# __________________________________________________________________________________________________
# dropout_59 (Dropout)            (None, 4, 4, 256)    0           conv2d_59[0][0]
# __________________________________________________________________________________________________
# conv2d_62 (Conv2D)              (None, 4, 4, 256)    131328      max_pooling2d_8[0][0]
# __________________________________________________________________________________________________
# conv2d_63 (Conv2D)              (None, 4, 4, 256)    131328      concatenate_4[0][0]
# __________________________________________________________________________________________________
# conv2d_57 (Conv2D)              (None, 4, 4, 256)    196864      dropout_58[0][0]
# __________________________________________________________________________________________________
# conv2d_58 (Conv2D)              (None, 4, 4, 256)    196864      dropout_58[0][0]
# __________________________________________________________________________________________________
# conv2d_60 (Conv2D)              (None, 4, 4, 256)    196864      dropout_59[0][0]
# __________________________________________________________________________________________________
# conv2d_61 (Conv2D)              (None, 4, 4, 256)    196864      dropout_59[0][0]
# __________________________________________________________________________________________________
# dropout_60 (Dropout)            (None, 4, 4, 256)    0           conv2d_62[0][0]
# __________________________________________________________________________________________________
# dropout_61 (Dropout)            (None, 4, 4, 256)    0           conv2d_63[0][0]
# __________________________________________________________________________________________________
# concatenate_5 (Concatenate)     (None, 4, 4, 1536)   0           conv2d_57[0][0]
#                                                                  conv2d_58[0][0]
#                                                                  conv2d_60[0][0]
#                                                                  conv2d_61[0][0]
#                                                                  dropout_60[0][0]
#                                                                  dropout_61[0][0]
# __________________________________________________________________________________________________
# dropout_62 (Dropout)            (None, 4, 4, 1536)   0           concatenate_5[0][0]
# __________________________________________________________________________________________________
# max_pooling2d_9 (MaxPooling2D)  (None, 4, 4, 1536)   0           dropout_62[0][0]
# __________________________________________________________________________________________________
# flatten_1 (Flatten)             (None, 24576)        0           max_pooling2d_9[0][0]
# __________________________________________________________________________________________________
# dense_2 (Dense)                 (None, 256)          6291712     flatten_1[0][0]
# __________________________________________________________________________________________________
# dropout_63 (Dropout)            (None, 256)          0           dense_2[0][0]
# __________________________________________________________________________________________________
# dense_3 (Dense)                 (None, 100)          25700       dropout_63[0][0]
# ==================================================================================================
# Total params: 9,190,724
# Trainable params: 9,190,724
# Non-trainable params: 0
# __________________________________________________________________________________________________

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
from tensorflow.keras.models import Sequential,Model
from tensorflow.keras.layers import Dense,Flatten,Input,Conv2D,MaxPool2D,concatenate,BatchNormalization,Dropout
from keras.layers.convolutional import MaxPooling2D
from keras.layers.merge import concatenate
from keras.layers import Concatenate, Dense, LSTM, Input, concatenate
from keras.layers import Conv2D

from tensorflow.keras import layers

import tensorflow.keras as keras

import tensorflow.keras as keras

from tensorflow.keras.preprocessing.image import ImageDataGenerator

from tensorflow.keras.layers import LeakyReLU

from tensorflow.keras.datasets import cifar100
from tensorflow.keras.utils import to_categorical

from tensorflow.keras.callbacks import EarlyStopping,ModelCheckpoint

from keras.optimizers import Adam,SGD


(X_train,Y_train),(X_test,Y_test)=cifar100.load_data()
y_train,y_test=to_categorical(Y_train),to_categorical(Y_test)
X_train,X_test=X_train/255,X_test/255


inputs=keras.Input(shape=(32,32,3))

a=layers.Conv2D(filters=32,kernel_size=(3,3),padding="same",strides=2,activation=LeakyReLU(alpha=0.1))(inputs)
a=layers.Dropout(0.01)(a)


a=layers.Conv2D(filters=32,kernel_size=(3,3),padding="same",strides=1,activation=LeakyReLU(alpha=0.1))(a)
a=layers.Dropout(0.01)(a)



a=layers.Conv2D(filters=32, kernel_size=(3,3), padding="same",strides=1,activation=LeakyReLU(alpha=0.1))(a)
a=layers.Dropout(0.01)(a)


a=layers.MaxPool2D(pool_size=(3,3),strides=(2,2))(a)


a=layers.Conv2D(filters=32, kernel_size=(3,3), padding="same",strides=1,activation=LeakyReLU(alpha=0.1))(a)
a=layers.Dropout(0.01)(a)



a=layers.Conv2D(filters=32, kernel_size=(3,3), padding="same",strides=2,activation=LeakyReLU(alpha=0.1))(a)
a=layers.Dropout(0.01)(a)



a=layers.Conv2D(filters=32, kernel_size=(3,3), padding="same",strides=1,activation=LeakyReLU(alpha=0.1))(a)
a=layers.Dropout(0.01)(a)



#inception-1
b=layers.Conv2D(64, (1,1), padding='same',strides=1,activation=LeakyReLU(alpha=0.1))(a)
b=layers.Dropout(0.01)(b)


b=layers.Conv2D(64, (3,3), padding='same',strides=1 ,activation=LeakyReLU(alpha=0.1))(b)
b=layers.Dropout(0.01)(b)


b=layers.Conv2D(64, (3,3), padding='same', strides=1,activation=LeakyReLU(alpha=0.1))(b)
b=layers.Dropout(0.01)(b)


c=layers.Conv2D(64, (1,1), padding='same', strides=1, activation=LeakyReLU(alpha=0.1))(a)
c=layers.Dropout(0.01)(c)

c=layers.Conv2D(64, (3,3), padding='same', strides=1, activation=LeakyReLU(alpha=0.1))(c)
c=layers.Dropout(0.01)(c)


d=layers.MaxPooling2D((3,3), strides=(1,1), padding='same')(a)
d=layers.Dropout(0.01)(d)

d=layers.Conv2D(64, (1,1), padding='same', strides=1, activation=LeakyReLU(alpha=0.1))(d)
d=layers.Dropout(0.01)(d)


e=layers.Conv2D(64, (1,1), padding='same', strides=1, activation=LeakyReLU(alpha=0.1))(a)
e=layers.Dropout(0.01)(e)


a=layers.concatenate([b, c, d,e],axis=3)
#a=Dropout(0.01)(a)


#inception-2
f=layers.Conv2D(128, (1,1), padding='same', strides=1, activation=LeakyReLU(alpha=0.1))(a)
f=layers.Dropout(0.01)(f)

f=layers.Conv2D(128, (1,7), padding='same', strides=1, activation=LeakyReLU(alpha=0.1))(f)
f=layers.Dropout(0.01)(f)


f=layers.Conv2D(128, (7,1), padding='same', strides=1, activation=LeakyReLU(alpha=0.1))(f)
f=layers.Dropout(0.01)(f)

f=layers.Conv2D(128, (1,7), padding='same', strides=1, activation=LeakyReLU(alpha=0.1))(f)
f=layers.Dropout(0.01)(f)


f=layers.Conv2D(128, (7,1), padding='same', strides=1, activation=LeakyReLU(alpha=0.1))(f)
f=layers.Dropout(0.01)(f)


g=layers.Conv2D(128, (1,1), padding='same', strides=1, activation=LeakyReLU(alpha=0.1))(a)
g=layers.Dropout(0.01)(g)

g=layers.Conv2D(128, (1,7), padding='same', strides=1,activation=LeakyReLU(alpha=0.1))(g)
g=layers.Dropout(0.01)(g)


g=layers.Conv2D(128, (7,1), padding='same', strides=1, activation=LeakyReLU(alpha=0.1))(g)

g=layers.Dropout(0.01)(g)


h=layers.MaxPooling2D((3,3), strides=(1,1), padding='same')(a)
h=layers.Dropout(0.01)(h)

h=layers.Conv2D(128, (1,1), padding='same', strides=1, activation=LeakyReLU(alpha=0.1))(h)
h=layers.Dropout(0.01)(h)


i=layers.Conv2D(128, (1,1), padding='same', strides=1, activation=LeakyReLU(alpha=0.1))(h)
i=layers.Dropout(0.01)(i)


a=layers.concatenate([f,g,h,i],axis=3)
#a=Dropout(0.01)(a)

#inception-3
j=layers.Conv2D(256, (1,1), padding='same', strides=1, activation=LeakyReLU(alpha=0.1))(a)
j=layers.Dropout(0.01)(j)


j=layers.Conv2D(256, (3,3), padding='same', strides=1, activation=LeakyReLU(alpha=0.1))(j)
j=layers.Dropout(0.01)(j)

k=layers.Conv2D(256, (1,3), padding='same', strides=1, activation=LeakyReLU(alpha=0.1))(j)
#k=Dropout(0.01)(k)

l=layers.Conv2D(256, (3,1), padding='same', strides=1, activation=LeakyReLU(alpha=0.1))(j)
#l=Dropout(0.01)(l)


m=layers.Conv2D(256, (1,1), padding='same', activation=LeakyReLU(alpha=0.1))(a)
m=layers.Dropout(0.01)(m)

n=layers.Conv2D(256, (1,3), padding='same', activation=LeakyReLU(alpha=0.1))(m)
#n=Dropout(0.01)(n)

o=layers.Conv2D(256, (3,1), padding='same', activation=LeakyReLU(alpha=0.1))(m)
#o=Dropout(0.01)(o)


p=layers.MaxPool2D((3,3), strides=(1,1), padding='same')(a)
p=layers.Conv2D(256, (1,1), padding='same', strides=1, activation=LeakyReLU(alpha=0.1))(p)
p=layers.Dropout(0.01)(p)


q=layers.Conv2D(256, (1,1), padding='same', strides=1, activation=LeakyReLU(alpha=0.1))(a)
q=layers.Dropout(0.01)(q)


a=layers.concatenate([k,l,n,o,p,q],axis=3)
a=layers.Dropout(0.01)(a)


a=layers.MaxPooling2D((8,8), strides=(1,1), padding='same')(a)
#a=Dropout(0.01)(a)


a=layers.Flatten()(a)

a=layers.Dense(units=256,activation=LeakyReLU(alpha=0.1))(a)
a=layers.Dropout(0.01)(a)


outputs=layers.Dense(y_train.shape[1],activation="softmax")(a)

model=keras.Model(inputs,outputs)

model.load_weights("../weights/Inception_SGD_dropout.hdf5")

y_true = y_test.argmax(-1)
y_pred = model.predict(X_test).argmax(-1)

from sklearn.metrics import classification_report,accuracy_score,recall_score,precision_score
print(classification_report(Y_test,y_pred))
print("Accuracy is {}".format(accuracy_score(Y_test,y_pred)))
print("Precision is {}".format(precision_score(Y_test,y_pred,average="weighted")))
print("Recall is {}".format(recall_score(Y_test,y_pred,average="weighted")))
# Out:
# Using TensorFlow backend.
# WARNING:tensorflow:From C:\Users\uamit\Anaconda3\lib\site-packages\tensorflow\python\ops\init_ops.py:1251: calling VarianceScaling.__init__ (from tensorflow.python.ops.init_ops) with dtype is deprecated and will be removed in a future version.
# Instructions for updating:
# Call initializer instance with the dtype argument instead of passing it to the constructor
#               precision    recall  f1-score   support
#
#            0       0.83      0.67      0.74       100
#            1       0.52      0.56      0.54       100
#            2       0.30      0.48      0.37       100
#            3       0.28      0.19      0.22       100
#            4       0.29      0.20      0.24       100
#            5       0.39      0.32      0.35       100
#            6       0.48      0.29      0.36       100
#            7       0.63      0.40      0.49       100
#            8       0.42      0.58      0.49       100
#            9       0.65      0.43      0.52       100
#           10       0.32      0.16      0.21       100
#           11       0.29      0.39      0.33       100
#           12       0.56      0.51      0.53       100
#           13       0.33      0.43      0.38       100
#           14       0.32      0.38      0.35       100
#           15       0.29      0.30      0.29       100
#           16       0.77      0.27      0.40       100
#           17       0.67      0.64      0.65       100
#           18       0.48      0.44      0.46       100
#           19       0.61      0.25      0.35       100
#           20       0.63      0.74      0.68       100
#           21       0.47      0.64      0.54       100
#           22       0.45      0.36      0.40       100
#           23       0.78      0.62      0.69       100
#           24       0.63      0.65      0.64       100
#           25       0.42      0.30      0.35       100
#           26       0.28      0.46      0.35       100
#           27       0.26      0.23      0.24       100
#           28       0.58      0.55      0.56       100
#           29       0.43      0.40      0.41       100
#           30       0.44      0.36      0.40       100
#           31       0.48      0.41      0.44       100
#           32       0.46      0.37      0.41       100
#           33       0.40      0.44      0.42       100
#           34       0.49      0.43      0.46       100
#           35       0.31      0.20      0.24       100
#           36       0.51      0.37      0.43       100
#           37       0.33      0.31      0.32       100
#           38       0.30      0.28      0.29       100
#           39       0.58      0.60      0.59       100
#           40       0.42      0.44      0.43       100
#           41       0.83      0.57      0.67       100
#           42       0.22      0.53      0.31       100
#           43       0.34      0.49      0.40       100
#           44       0.21      0.13      0.16       100
#           45       0.24      0.33      0.28       100
#           46       0.29      0.35      0.32       100
#           47       0.64      0.34      0.44       100
#           48       0.42      0.82      0.56       100
#           49       0.59      0.63      0.61       100
#           50       0.26      0.26      0.26       100
#           51       0.30      0.51      0.38       100
#           52       0.43      0.84      0.57       100
#           53       0.50      0.88      0.64       100
#           54       0.53      0.62      0.57       100
#           55       0.38      0.06      0.10       100
#           56       0.70      0.69      0.70       100
#           57       0.46      0.47      0.46       100
#           58       0.52      0.44      0.48       100
#           59       0.45      0.37      0.41       100
#           60       0.82      0.79      0.81       100
#           61       0.49      0.58      0.53       100
#           62       0.54      0.58      0.56       100
#           63       0.46      0.38      0.42       100
#           64       0.42      0.15      0.22       100
#           65       0.25      0.25      0.25       100
#           66       0.35      0.24      0.28       100
#           67       0.59      0.32      0.42       100
#           68       0.87      0.81      0.84       100
#           69       0.67      0.66      0.67       100
#           70       0.49      0.53      0.51       100
#           71       0.61      0.67      0.64       100
#           72       0.20      0.09      0.12       100
#           73       0.49      0.36      0.41       100
#           74       0.20      0.30      0.24       100
#           75       0.80      0.64      0.71       100
#           76       0.69      0.68      0.68       100
#           77       0.31      0.30      0.30       100
#           78       0.23      0.33      0.27       100
#           79       0.52      0.27      0.36       100
#           80       0.22      0.11      0.15       100
#           81       0.32      0.50      0.39       100
#           82       0.85      0.73      0.78       100
#           83       0.39      0.48      0.43       100
#           84       0.48      0.45      0.46       100
#           85       0.52      0.56      0.54       100
#           86       0.32      0.50      0.39       100
#           87       0.41      0.59      0.49       100
#           88       0.36      0.55      0.43       100
#           89       0.49      0.60      0.54       100
#           90       0.58      0.37      0.45       100
#           91       0.63      0.49      0.55       100
#           92       0.36      0.35      0.36       100
#           93       0.35      0.22      0.27       100
#           94       0.72      0.83      0.77       100
#           95       0.47      0.64      0.54       100
#           96       0.69      0.11      0.19       100
#           97       0.31      0.49      0.38       100
#           98       0.23      0.24      0.23       100
#           99       0.40      0.43      0.41       100
#
#     accuracy                           0.45     10000
#    macro avg       0.46      0.45      0.44     10000
# weighted avg       0.46      0.45      0.44     10000
#
# Accuracy is 0.4455
# Precision is 0.46485644736740517
# Recall is 0.4455
