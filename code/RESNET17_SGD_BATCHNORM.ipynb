# %%
from tensorflow.keras.models import Model
from tensorflow.keras.layers import Conv2D,Dense,MaxPool2D,AveragePooling2D,Flatten
import tensorflow.keras as keras
from tensorflow.keras.datasets import cifar100
from tensorflow.keras.utils import to_categorical
from tensorflow.keras import layers

from tensorflow.keras.preprocessing.image import ImageDataGenerator
from tensorflow.keras.optimizers import SGD

from tensorflow.keras.layers import LeakyReLU,BatchNormalization

from tensorflow.keras.callbacks import EarlyStopping,ModelCheckpoint

# %%
# Out:
# WARNING:tensorflow:`period` argument is deprecated. Please use `save_freq` to specify the frequency in number of batches seen.

# %%
(X_train,Y_train),(X_test,Y_test)=cifar100.load_data()

X_train,X_test=X_train/255,X_test/255
y_train,y_test=to_categorical(Y_train),to_categorical(Y_test)

# %%
aug_data=ImageDataGenerator(rotation_range=15,horizontal_flip=True,width_shift_range=0.1,height_shift_range=0.1,zoom_range=0.3)
aug_data.fit(X_train)

# %%
shape=(32,32,3)

inputs = keras.Input(shape=shape)

a=layers.Conv2D(32,(3,3),strides=1,padding="same",activation="relu")(inputs)  #1
a=layers.BatchNormalization()(a)
a=layers.Conv2D(32,(3,3),strides=1,padding="same",activation="relu")(a)   #2
a=layers.BatchNormalization()(a)
a_temp=a
a=layers.Conv2D(32,(3,3),strides=1,padding="same",activation="relu")(a)#\3
a=layers.BatchNormalization()(a)
a=layers.Conv2D(32,(3,3),strides=1,padding="same")(a)#
a=layers.BatchNormalization()(a)

a=layers.Add()([a,a_temp])
a=layers.Activation("relu")(a
#
a=layers.BatchNormalization()(a)


b=layers.Conv2D(64,(3,3),strides=1,padding="same",activation="relu")(a) #1
                               
#a_temp=a
##########################################################################
a=layers.Conv2D(64,(3,3),strides=1,padding="same",activation="relu")(a) #5
a=layers.BatchNormalization()(a)

a=layers.Conv2D(64,(3,3),strides=1,padding="same")(a) #6
a=layers.BatchNormalization()(a)

a=layers.Add()([b,a])
a=layers.Activation("relu")(a)
#
a=layers.BatchNormalization()(a)

a_temp=a
a=layers.Conv2D(64,(3,3),strides=1,padding="same",activation="relu")(a) #7
a=layers.BatchNormalization()(a)

a=layers.Conv2D(64,(3,3),strides=1,padding="same")(a) #8
a=layers.BatchNormalization()(a)

a=layers.Add()([a,a_temp])
a=layers.Activation("relu")(a)
#
a=layers.BatchNormalization()(a)


b=layers.Conv2D(128,(3,3),strides=1,padding="same",activation="relu")(a) #2

###############################################################################

a=layers.Conv2D(128,(3,3),strides=1,padding="same",activation="relu")(a) #9
a=layers.BatchNormalization()(a)

a=layers.Conv2D(128,(3,3),strides=1,padding="same")(a) #10
a=layers.BatchNormalization()(a)

a=layers.Add()([b,a])
a=layers.Activation("relu")(a)
#
a=layers.BatchNormalization()(a)

a_temp=a
a=layers.Conv2D(128,(3,3),strides=1,padding="same",activation="relu")(a) #11
a=layers.BatchNormalization()(a)

a=layers.Conv2D(128,(3,3),strides=1,padding="same")(a) #12
a=layers.BatchNormalization()(a)

a=layers.Add()([a,a_temp])
a=layers.Activation("relu")(a)
#
a=layers.BatchNormalization()(a)


b=layers.Conv2D(256,(3,3),strides=1,padding="same",activation="relu")(a) #3

#################################################################################

a=layers.Conv2D(256,(3,3),strides=1,padding="same",activation="relu")(a) #
a=layers.BatchNormalization()(a)

a=layers.Conv2D(256,(3,3),strides=1,padding="same")(a) #14
a=layers.BatchNormalization()(a)

a=layers.Add()([b,a])
a=layers.Activation("relu")(a)
#
a=layers.BatchNormalization()(a)

a_temp=a
a=layers.Conv2D(256,(3,3),strides=1,padding="same",activation="relu")(a) #15
a=layers.BatchNormalization()(a)

a=layers.Conv2D(256,(3,3),strides=1,padding="same")(a) #16
a=layers.BatchNormalization()(a)

a=layers.Add()([a,a_temp])
a=layers.Activation("relu")(a)
#
a=layers.BatchNormalization()(a)

############################################################3
a=layers.AveragePooling2D(pool_size=(2,2),strides=1,padding="same")(a)
a=layers.BatchNormalization()(a)

a=Flatten()(a)

#############################################################

a=layers.Dense(512,activation="relu")(a)
a=layers.BatchNormalization()(a)

outputs=layers.Dense(y_train.shape[1],activation="softmax")(a)


model = keras.Model(inputs, outputs)

# %%
sgd = SGD(lr=0.01, momentum=0.91,clipvalue=0.6)


model.compile(loss="categorical_crossentropy",optimizer=sgd,metrics=["accuracy"])
call=EarlyStopping(monitor="val_loss",verbose=1,mode="auto",patience=5,restore_best_weights=True)
checkpoint=ModelCheckpoint('SGD WITH_BATCHNORM_RESNET.hdf5',monitor='val_accuracy',verbose=1,save_best_only=True,save_weights_only=True,model='auto',period=1)
# Out:
# WARNING:tensorflow:`period` argument is deprecated. Please use `save_freq` to specify the frequency in number of batches seen.

# %%
model.fit_generator(aug_data.flow(X_train,y_train,batch_size=128),steps_per_epoch=len(X_train)/128,epochs=80,validation_data=(X_test,y_test),verbose=1,callbacks=[call,checkpoint])
# Out:
# Epoch 1/80
#   2/390 [..............................] - ETA: 1:17 - loss: 5.6976 - accuracy: 0.0078WARNING:tensorflow:Callbacks method `on_train_batch_end` is slow compared to the batch time (batch time: 0.1325s vs `on_train_batch_end` time: 0.2653s). Check your callbacks.
# 391/390 [==============================] - ETA: 0s - loss: 3.6590 - accuracy: 0.1635
# Epoch 00001: val_accuracy improved from -inf to 0.16470, saving model to SGD WITH_BATCHNORM_RESNET.hdf5
# 391/390 [==============================] - 177s 452ms/step - loss: 3.6590 - accuracy: 0.1635 - val_loss: 3.5456 - val_accuracy: 0.1647
# Epoch 2/80
# 391/390 [==============================] - ETA: 0s - loss: 2.9940 - accuracy: 0.2721
# Epoch 00002: val_accuracy improved from 0.16470 to 0.31470, saving model to SGD WITH_BATCHNORM_RESNET.hdf5
# 391/390 [==============================] - 184s 470ms/step - loss: 2.9940 - accuracy: 0.2721 - val_loss: 2.7820 - val_accuracy: 0.3147
# Epoch 3/80
# 391/390 [==============================] - ETA: 0s - loss: 2.5930 - accuracy: 0.3470
# Epoch 00003: val_accuracy improved from 0.31470 to 0.36700, saving model to SGD WITH_BATCHNORM_RESNET.hdf5
# 391/390 [==============================] - 184s 471ms/step - loss: 2.5930 - accuracy: 0.3470 - val_loss: 2.5834 - val_accuracy: 0.3670
# Epoch 4/80
# 391/390 [==============================] - ETA: 0s - loss: 2.3103 - accuracy: 0.4013
# Epoch 00004: val_accuracy improved from 0.36700 to 0.43430, saving model to SGD WITH_BATCHNORM_RESNET.hdf5
# 391/390 [==============================] - 184s 471ms/step - loss: 2.3103 - accuracy: 0.4013 - val_loss: 2.2541 - val_accuracy: 0.4343
# Epoch 5/80
# 391/390 [==============================] - ETA: 0s - loss: 2.0886 - accuracy: 0.4468
# Epoch 00005: val_accuracy improved from 0.43430 to 0.44400, saving model to SGD WITH_BATCHNORM_RESNET.hdf5
# 391/390 [==============================] - 185s 473ms/step - loss: 2.0886 - accuracy: 0.4468 - val_loss: 2.1639 - val_accuracy: 0.4440
# Epoch 6/80
# 391/390 [==============================] - ETA: 0s - loss: 1.9123 - accuracy: 0.4882
# Epoch 00006: val_accuracy improved from 0.44400 to 0.49480, saving model to SGD WITH_BATCHNORM_RESNET.hdf5
# 391/390 [==============================] - 185s 473ms/step - loss: 1.9123 - accuracy: 0.4882 - val_loss: 1.9747 - val_accuracy: 0.4948
# Epoch 7/80
# 391/390 [==============================] - ETA: 0s - loss: 1.7699 - accuracy: 0.5187
# Epoch 00007: val_accuracy improved from 0.49480 to 0.50920, saving model to SGD WITH_BATCHNORM_RESNET.hdf5
# 391/390 [==============================] - 185s 473ms/step - loss: 1.7699 - accuracy: 0.5187 - val_loss: 1.8522 - val_accuracy: 0.5092
# Epoch 8/80
# 391/390 [==============================] - ETA: 0s - loss: 1.6463 - accuracy: 0.5482
# Epoch 00008: val_accuracy improved from 0.50920 to 0.51080, saving model to SGD WITH_BATCHNORM_RESNET.hdf5
# 391/390 [==============================] - 184s 471ms/step - loss: 1.6463 - accuracy: 0.5482 - val_loss: 1.9299 - val_accuracy: 0.5108
# Epoch 9/80
# 391/390 [==============================] - ETA: 0s - loss: 1.5384 - accuracy: 0.5712
# Epoch 00009: val_accuracy improved from 0.51080 to 0.52750, saving model to SGD WITH_BATCHNORM_RESNET.hdf5
# 391/390 [==============================] - 185s 472ms/step - loss: 1.5384 - accuracy: 0.5712 - val_loss: 1.8219 - val_accuracy: 0.5275
# Epoch 10/80
# 391/390 [==============================] - ETA: 0s - loss: 1.4414 - accuracy: 0.5975
# Epoch 00010: val_accuracy improved from 0.52750 to 0.53530, saving model to SGD WITH_BATCHNORM_RESNET.hdf5
# 391/390 [==============================] - 184s 471ms/step - loss: 1.4414 - accuracy: 0.5975 - val_loss: 1.8278 - val_accuracy: 0.5353
# Epoch 11/80
# 391/390 [==============================] - ETA: 0s - loss: 1.3592 - accuracy: 0.6186
# Epoch 00011: val_accuracy improved from 0.53530 to 0.54130, saving model to SGD WITH_BATCHNORM_RESNET.hdf5
# 391/390 [==============================] - 185s 473ms/step - loss: 1.3592 - accuracy: 0.6186 - val_loss: 1.7926 - val_accuracy: 0.5413
# Epoch 12/80
# 391/390 [==============================] - ETA: 0s - loss: 1.2779 - accuracy: 0.6415
# Epoch 00012: val_accuracy improved from 0.54130 to 0.56390, saving model to SGD WITH_BATCHNORM_RESNET.hdf5
# 391/390 [==============================] - 185s 472ms/step - loss: 1.2779 - accuracy: 0.6415 - val_loss: 1.7218 - val_accuracy: 0.5639
# Epoch 13/80
# 391/390 [==============================] - ETA: 0s - loss: 1.2050 - accuracy: 0.6574
# Epoch 00013: val_accuracy improved from 0.56390 to 0.57060, saving model to SGD WITH_BATCHNORM_RESNET.hdf5
# 391/390 [==============================] - 184s 472ms/step - loss: 1.2050 - accuracy: 0.6574 - val_loss: 1.6530 - val_accuracy: 0.5706
# Epoch 14/80
# 391/390 [==============================] - ETA: 0s - loss: 1.1403 - accuracy: 0.6759
# Epoch 00014: val_accuracy improved from 0.57060 to 0.57180, saving model to SGD WITH_BATCHNORM_RESNET.hdf5
# 391/390 [==============================] - 184s 471ms/step - loss: 1.1403 - accuracy: 0.6759 - val_loss: 1.6744 - val_accuracy: 0.5718
# Epoch 15/80
# 391/390 [==============================] - ETA: 0s - loss: 1.0879 - accuracy: 0.6868
# Epoch 00015: val_accuracy did not improve from 0.57180
# 391/390 [==============================] - 183s 467ms/step - loss: 1.0879 - accuracy: 0.6868 - val_loss: 1.7131 - val_accuracy: 0.5704
# Epoch 16/80
# 391/390 [==============================] - ETA: 0s - loss: 1.0308 - accuracy: 0.7013
# Epoch 00016: val_accuracy improved from 0.57180 to 0.57370, saving model to SGD WITH_BATCHNORM_RESNET.hdf5
# 391/390 [==============================] - 184s 471ms/step - loss: 1.0308 - accuracy: 0.7013 - val_loss: 1.7066 - val_accuracy: 0.5737
# Epoch 17/80
# 391/390 [==============================] - ETA: 0s - loss: 0.9676 - accuracy: 0.7182
# Epoch 00017: val_accuracy improved from 0.57370 to 0.57910, saving model to SGD WITH_BATCHNORM_RESNET.hdf5
# 391/390 [==============================] - 184s 471ms/step - loss: 0.9676 - accuracy: 0.7182 - val_loss: 1.7158 - val_accuracy: 0.5791
# Epoch 18/80
# 391/390 [==============================] - ETA: 0s - loss: 0.9186 - accuracy: 0.7319Restoring model weights from the end of the best epoch.
#
# Epoch 00018: val_accuracy improved from 0.57910 to 0.59290, saving model to SGD WITH_BATCHNORM_RESNET.hdf5
# 391/390 [==============================] - 184s 469ms/step - loss: 0.9186 - accuracy: 0.7319 - val_loss: 1.6608 - val_accuracy: 0.5929
# Epoch 00018: early stopping

# %%
y_true = y_test.argmax(-1)
y_pred = model.predict(X_test).argmax(-1)


from sklearn.metrics import classification_report,accuracy_score,recall_score,precision_score
print(classification_report(Y_test,y_pred))
print("Accuracy is {}".format(accuracy_score(Y_test,y_pred)))
print("Precision is {}".format(precision_score(Y_test,y_pred,average="weighted")))
print("Recall is {}".format(recall_score(Y_test,y_pred,average="weighted")))
# Out:
#               precision    recall  f1-score   support
#
#            0       0.81      0.77      0.79       100
#            1       0.70      0.72      0.71       100
#            2       0.44      0.48      0.46       100
#            3       0.46      0.35      0.40       100
#            4       0.36      0.38      0.37       100
#            5       0.45      0.60      0.51       100
#            6       0.68      0.67      0.67       100
#            7       0.59      0.65      0.62       100
#            8       0.66      0.75      0.70       100
#            9       0.75      0.72      0.73       100
#           10       0.45      0.32      0.37       100
#           11       0.39      0.44      0.41       100
#           12       0.53      0.72      0.61       100
#           13       0.39      0.62      0.48       100
#           14       0.42      0.61      0.50       100
#           15       0.49      0.49      0.49       100
#           16       0.54      0.70      0.61       100
#           17       0.79      0.67      0.72       100
#           18       0.54      0.60      0.57       100
#           19       0.43      0.65      0.52       100
#           20       0.79      0.77      0.78       100
#           21       0.81      0.67      0.73       100
#           22       0.36      0.70      0.48       100
#           23       0.83      0.59      0.69       100
#           24       0.88      0.71      0.78       100
#           25       0.38      0.41      0.40       100
#           26       0.38      0.55      0.45       100
#           27       0.36      0.41      0.38       100
#           28       0.75      0.74      0.74       100
#           29       0.67      0.45      0.54       100
#           30       0.67      0.41      0.51       100
#           31       0.86      0.37      0.52       100
#           32       0.53      0.57      0.55       100
#           33       0.53      0.59      0.56       100
#           34       0.70      0.60      0.65       100
#           35       0.36      0.27      0.31       100
#           36       0.85      0.57      0.68       100
#           37       0.55      0.55      0.55       100
#           38       0.52      0.27      0.36       100
#           39       0.55      0.85      0.67       100
#           40       0.67      0.45      0.54       100
#           41       0.81      0.79      0.80       100
#           42       0.35      0.77      0.48       100
#           43       0.69      0.55      0.61       100
#           44       0.36      0.31      0.34       100
#           45       0.36      0.63      0.46       100
#           46       0.49      0.31      0.38       100
#           47       0.51      0.67      0.58       100
#           48       0.63      0.93      0.75       100
#           49       0.70      0.69      0.70       100
#           50       0.43      0.32      0.37       100
#           51       0.62      0.56      0.59       100
#           52       0.57      0.66      0.61       100
#           53       0.73      0.82      0.77       100
#           54       0.65      0.72      0.68       100
#           55       0.32      0.12      0.17       100
#           56       0.83      0.71      0.76       100
#           57       0.70      0.57      0.63       100
#           58       0.71      0.60      0.65       100
#           59       0.76      0.39      0.52       100
#           60       0.83      0.81      0.82       100
#           61       0.47      0.69      0.56       100
#           62       0.49      0.75      0.59       100
#           63       0.58      0.51      0.54       100
#           64       0.56      0.36      0.44       100
#           65       0.58      0.35      0.44       100
#           66       0.64      0.49      0.55       100
#           67       0.56      0.39      0.46       100
#           68       0.92      0.85      0.89       100
#           69       0.79      0.70      0.74       100
#           70       0.79      0.46      0.58       100
#           71       0.76      0.71      0.73       100
#           72       0.28      0.29      0.28       100
#           73       0.45      0.48      0.46       100
#           74       0.35      0.44      0.39       100
#           75       0.76      0.75      0.75       100
#           76       0.81      0.77      0.79       100
#           77       0.50      0.36      0.42       100
#           78       0.30      0.51      0.38       100
#           79       0.68      0.55      0.61       100
#           80       0.69      0.27      0.39       100
#           81       0.38      0.78      0.51       100
#           82       0.80      0.83      0.81       100
#           83       0.59      0.54      0.57       100
#           84       0.67      0.57      0.62       100
#           85       0.66      0.75      0.70       100
#           86       0.51      0.64      0.57       100
#           87       0.73      0.60      0.66       100
#           88       0.58      0.69      0.63       100
#           89       0.73      0.43      0.54       100
#           90       0.66      0.60      0.63       100
#           91       0.71      0.64      0.67       100
#           92       0.60      0.51      0.55       100
#           93       0.44      0.41      0.42       100
#           94       0.69      0.88      0.77       100
#           95       0.68      0.64      0.66       100
#           96       0.62      0.36      0.46       100
#           97       0.80      0.45      0.58       100
#           98       0.35      0.19      0.25       100
#           99       0.48      0.53      0.50       100
#
#     accuracy                           0.57     10000
#    macro avg       0.60      0.57      0.57     10000
# weighted avg       0.60      0.57      0.57     10000
#
# Accuracy is 0.5706
# Precision is 0.5954532049977297
# Recall is 0.5706

# %%
from tensorflow.keras.models import Model
from tensorflow.keras.layers import Conv2D,Dense,MaxPool2D,AveragePooling2D,Flatten
import tensorflow.keras as keras
from tensorflow.keras.datasets import cifar100
from tensorflow.keras.utils import to_categorical
from tensorflow.keras import layers

from tensorflow.keras.preprocessing.image import ImageDataGenerator
from tensorflow.keras.optimizers import SGD

from tensorflow.keras.layers import LeakyReLU,BatchNormalization

from tensorflow.keras.callbacks import EarlyStopping,ModelCheckpoint

(X_train,Y_train),(X_test,Y_test)=cifar100.load_data()

X_train,X_test=X_train/255,X_test/255
y_train,y_test=to_categorical(Y_train),to_categorical(Y_test)

shape=(32,32,3)

inputs = keras.Input(shape=shape)

a=layers.Conv2D(32,(3,3),strides=1,padding="same",activation="relu")(inputs)  #1
a=layers.BatchNormalization()(a)
a=layers.Conv2D(32,(3,3),strides=1,padding="same",activation="relu")(a)   #2
a=layers.BatchNormalization()(a)
a_temp=a
a=layers.Conv2D(32,(3,3),strides=1,padding="same",activation="relu")(a)#\3
a=layers.BatchNormalization()(a)
a=layers.Conv2D(32,(3,3),strides=1,padding="same")(a)#
a=layers.BatchNormalization()(a)

a=layers.Add()([a,a_temp])
a=layers.Activation("relu")(a)
#
a=layers.BatchNormalization()(a)


b=layers.Conv2D(64,(3,3),strides=1,padding="same",activation="relu")(a) #1
                               
#a_temp=a
##########################################################################
a=layers.Conv2D(64,(3,3),strides=1,padding="same",activation="relu")(a) #5
a=layers.BatchNormalization()(a)

a=layers.Conv2D(64,(3,3),strides=1,padding="same")(a) #6
a=layers.BatchNormalization()(a)

a=layers.Add()([b,a])
a=layers.Activation("relu")(a)
#
a=layers.BatchNormalization()(a)

a_temp=a
a=layers.Conv2D(64,(3,3),strides=1,padding="same",activation="relu")(a) #7
a=layers.BatchNormalization()(a)

a=layers.Conv2D(64,(3,3),strides=1,padding="same")(a) #8
a=layers.BatchNormalization()(a)

a=layers.Add()([a,a_temp])
a=layers.Activation("relu")(a)
#
a=layers.BatchNormalization()(a)


b=layers.Conv2D(128,(3,3),strides=1,padding="same",activation="relu")(a) #2

###############################################################################

a=layers.Conv2D(128,(3,3),strides=1,padding="same",activation="relu")(a) #9
a=layers.BatchNormalization()(a)

a=layers.Conv2D(128,(3,3),strides=1,padding="same")(a) #10
a=layers.BatchNormalization()(a)

a=layers.Add()([b,a])
a=layers.Activation("relu")(a)
#
a=layers.BatchNormalization()(a)

a_temp=a
a=layers.Conv2D(128,(3,3),strides=1,padding="same",activation="relu")(a) #11
a=layers.BatchNormalization()(a)

a=layers.Conv2D(128,(3,3),strides=1,padding="same")(a) #12
a=layers.BatchNormalization()(a)

a=layers.Add()([a,a_temp])
a=layers.Activation("relu")(a)
#
a=layers.BatchNormalization()(a)


b=layers.Conv2D(256,(3,3),strides=1,padding="same",activation="relu")(a) #3

#################################################################################

a=layers.Conv2D(256,(3,3),strides=1,padding="same",activation="relu")(a) #
a=layers.BatchNormalization()(a)

a=layers.Conv2D(256,(3,3),strides=1,padding="same")(a) #14
a=layers.BatchNormalization()(a)

a=layers.Add()([b,a])
a=layers.Activation("relu")(a)
#
a=layers.BatchNormalization()(a)

a_temp=a
a=layers.Conv2D(256,(3,3),strides=1,padding="same",activation="relu")(a) #15
a=layers.BatchNormalization()(a)

a=layers.Conv2D(256,(3,3),strides=1,padding="same")(a) #16
a=layers.BatchNormalization()(a)

a=layers.Add()([a,a_temp])
a=layers.Activation("relu")(a)
#
a=layers.BatchNormalization()(a)

############################################################3
a=layers.AveragePooling2D(pool_size=(2,2),strides=1,padding="same")(a)
a=layers.BatchNormalization()(a)

a=Flatten()(a)

#############################################################

a=layers.Dense(512,activation="relu")(a)
a=layers.BatchNormalization()(a)

outputs=layers.Dense(y_train.shape[1],activation="softmax")(a)


model = keras.Model(inputs, outputs)

model.load_weights('../weights/SGD WITH_BATCHNORM_RESNET.hdf5')

y_true = y_test.argmax(-1)
y_pred = model.predict(X_test).argmax(-1)


from sklearn.metrics import classification_report,accuracy_score,recall_score,precision_score
print(classification_report(Y_test,y_pred))
print("Accuracy is {}".format(accuracy_score(Y_test,y_pred)))
print("Precision is {}".format(precision_score(Y_test,y_pred,average="weighted")))
print("Recall is {}".format(recall_score(Y_test,y_pred,average="weighted")))
# Out:
#               precision    recall  f1-score   support
#
#            0       0.81      0.77      0.79       100
#            1       0.70      0.72      0.71       100
#            2       0.44      0.48      0.46       100
#            3       0.46      0.35      0.40       100
#            4       0.36      0.38      0.37       100
#            5       0.45      0.60      0.51       100
#            6       0.68      0.67      0.67       100
#            7       0.59      0.65      0.62       100
#            8       0.66      0.75      0.70       100
#            9       0.75      0.72      0.73       100
#           10       0.45      0.32      0.37       100
#           11       0.39      0.44      0.41       100
#           12       0.53      0.72      0.61       100
#           13       0.39      0.62      0.48       100
#           14       0.42      0.61      0.50       100
#           15       0.49      0.49      0.49       100
#           16       0.54      0.70      0.61       100
#           17       0.79      0.67      0.72       100
#           18       0.54      0.60      0.57       100
#           19       0.43      0.65      0.52       100
#           20       0.79      0.77      0.78       100
#           21       0.81      0.67      0.73       100
#           22       0.36      0.70      0.48       100
#           23       0.83      0.59      0.69       100
#           24       0.88      0.71      0.78       100
#           25       0.38      0.41      0.40       100
#           26       0.38      0.55      0.45       100
#           27       0.36      0.41      0.38       100
#           28       0.75      0.74      0.74       100
#           29       0.67      0.45      0.54       100
#           30       0.67      0.41      0.51       100
#           31       0.86      0.37      0.52       100
#           32       0.53      0.57      0.55       100
#           33       0.53      0.59      0.56       100
#           34       0.70      0.60      0.65       100
#           35       0.36      0.27      0.31       100
#           36       0.85      0.57      0.68       100
#           37       0.55      0.55      0.55       100
#           38       0.52      0.27      0.36       100
#           39       0.55      0.85      0.67       100
#           40       0.67      0.45      0.54       100
#           41       0.81      0.79      0.80       100
#           42       0.35      0.77      0.48       100
#           43       0.69      0.55      0.61       100
#           44       0.36      0.31      0.34       100
#           45       0.36      0.63      0.46       100
#           46       0.49      0.31      0.38       100
#           47       0.51      0.67      0.58       100
#           48       0.63      0.93      0.75       100
#           49       0.70      0.69      0.70       100
#           50       0.43      0.32      0.37       100
#           51       0.62      0.56      0.59       100
#           52       0.57      0.66      0.61       100
#           53       0.73      0.82      0.77       100
#           54       0.65      0.72      0.68       100
#           55       0.32      0.12      0.17       100
#           56       0.83      0.71      0.76       100
#           57       0.70      0.57      0.63       100
#           58       0.71      0.60      0.65       100
#           59       0.76      0.39      0.52       100
#           60       0.83      0.81      0.82       100
#           61       0.47      0.69      0.56       100
#           62       0.49      0.75      0.59       100
#           63       0.58      0.51      0.54       100
#           64       0.56      0.36      0.44       100
#           65       0.58      0.35      0.44       100
#           66       0.64      0.49      0.55       100
#           67       0.56      0.39      0.46       100
#           68       0.92      0.85      0.89       100
#           69       0.79      0.70      0.74       100
#           70       0.79      0.46      0.58       100
#           71       0.76      0.71      0.73       100
#           72       0.28      0.29      0.28       100
#           73       0.45      0.48      0.46       100
#           74       0.35      0.44      0.39       100
#           75       0.76      0.75      0.75       100
#           76       0.81      0.77      0.79       100
#           77       0.50      0.36      0.42       100
#           78       0.30      0.51      0.38       100
#           79       0.68      0.55      0.61       100
#           80       0.69      0.27      0.39       100
#           81       0.38      0.78      0.51       100
#           82       0.80      0.83      0.81       100
#           83       0.59      0.54      0.57       100
#           84       0.67      0.57      0.62       100
#           85       0.66      0.75      0.70       100
#           86       0.51      0.64      0.57       100
#           87       0.73      0.60      0.66       100
#           88       0.58      0.69      0.63       100
#           89       0.73      0.43      0.54       100
#           90       0.66      0.60      0.63       100
#           91       0.71      0.64      0.67       100
#           92       0.60      0.51      0.55       100
#           93       0.44      0.41      0.42       100
#           94       0.69      0.88      0.77       100
#           95       0.68      0.64      0.66       100
#           96       0.62      0.36      0.46       100
#           97       0.80      0.45      0.58       100
#           98       0.35      0.19      0.25       100
#           99       0.48      0.53      0.50       100
#
#     accuracy                           0.57     10000
#    macro avg       0.60      0.57      0.57     10000
# weighted avg       0.60      0.57      0.57     10000
#
# Accuracy is 0.5706
# Precision is 0.5954532049977297
# Recall is 0.5706
